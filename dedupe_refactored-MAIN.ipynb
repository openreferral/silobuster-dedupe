# %%
from libs.connector.postgres_connector import PostgresToPostgresConnector
from libs.handler.postgres_handler import PostgresHandler
from libs.log_handler.log_handler import LogHandler

from libs.dedupe.ml.names_orgs.names_orgs import dedupe_names_orgs

import pandas as pd

log_handler = PostgresHandler(
    host = 'silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com',
    port = '25060',
    db = 'defaultdb',
    password = 'AVNS_2Lh_hY8r7RVKSfLwbJM',
    username = 'doadmin',
    env_prefix = 'LOG_POSTGRES'
)

logger = LogHandler(db_handler=log_handler)


input_qry = '''
    SELECT
        o.id as organization_id,
        o.name as name,
        o.url as o_url,
        l.id as location_id,
        l.latitude,
        l.longitude,
        a.address_1,
        a.address_2,
        a.city,
        a.state_province,
        a.postal_code
    FROM organization o
    JOIN location l on l.organization_id = o.id
    JOIN address a on a.location_id = l.id
    WHERE type = 'physical'
    '''

output_qry = '''
    INSERT INTO logs (id, job_id, iteration_id, step_name, contributor_name, log_message) VALUES (%s, %s, %s, %s, %s, %s)
'''

input_handler = PostgresHandler(
    host = 'silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com',
    port = '25060',
    db = 'defaultdb',
    password = 'AVNS_2Lh_hY8r7RVKSfLwbJM',
    username = 'doadmin',
    query = input_qry,
    env_prefix = 'INPUT_POSTGRES'
)

output_handler = PostgresHandler(
    host = 'silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com',
    port = '25060',
    db = 'defaultdb',
    password = 'AVNS_2Lh_hY8r7RVKSfLwbJM',
    username = 'doadmin',
    query = output_qry,
    env_prefix='OUTPUT_POSTGRES'
)

print (input_handler)
print (output_handler)
# Out:
# Host: silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com
# Port: 25060
# Database: defaultdb
# Username: doadmin
# Connection Alive? Yes
# Host: silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com
# Port: 25060
# Database: defaultdb
# Username: doadmin
# Connection Alive? Yes

# %%
print (input_qry)
connector = PostgresToPostgresConnector(
    input_handler=input_handler, 
    log_handler=logger,
    output_handler=output_handler,
)
# Out:
#     SELECT
#         o.id as organization_id,
#         o.name as name,
#         o.url as o_url,
#         l.id as location_id,
#         l.latitude,
#         l.longitude,
#         a.address_1,
#         a.address_2,
#         a.city,
#         a.state_province,
#         a.postal_code
#     FROM organization o
#     JOIN location l on l.organization_id = o.id
#     JOIN address a on a.location_id = l.id
#     WHERE type = 'physical'

# %%
print (connector.input_handler)
# Out:
# Host: silobuster-dev-db-do-user-12298230-0.b.db.ondigitalocean.com
# Port: 25060
# Database: defaultdb
# Username: doadmin
# Connection Alive? Yes

# %%
connector.df
# Out:
#                       organization_id  \
# 0    46c4acdfa7407bb1f0de32a2467c7987
# 1    0311533a6d3626101e12996e914c1477
# 2    c5fce969171a54cfae5440cacfd45585
# 3    7536dcaf0707e39f30ec2936a5b6774e
# 4    b3fa2d0531dc59d40be538c89a15e383
# ..                                ...
# 247  153d5b0e27aac9dce9c5bb0780140539
# 248  c37caada0542c22e1c2251a4e87a82a7
# 249  82a20fa5edd54a7ae2447e4fcb219828
# 250  b2deadfeed40efe829bcd1a0bff93f12
# 251  09f52f8f4172b0876578c593ec08ca00
#
#                                                   name  \
# 0                                      *REQUIRED* text
# 1    Depressive and Bipolar Support Alliance Whatco...
# 2             Bellingham Parks and Recreation Division
# 3                          Mount Baker School District
# 4                         Bellingham Technical College
# ..                                                 ...
# 247        Bridges Treatment and Recovery (Bellingham)
# 248          Bridges Treatment and Recovery (Ferndale)
# 249        Lake Whatcom Residential & Treatment Center
# 250                                         Lummi Care
# 251                        Nooksack Tribe (Genesis II)
#
#                                                  o_url  \
# 0                               http://some.domain.com
# 1                           http://www.dbsalliance.org
# 2                  https://cob.org/services/recreation
# 3                        http://www.mtbaker.wednet.edu
# 4                                  https://www.btc.edu
# ..                                                 ...
# 247                   https://www.bridgestreatment.com
# 248                   https://www.bridgestreatment.com
# 249       https://lwrtc.org/services/medical-services/
# 250   https://www.lummi-nsn.gov/Website.php?PageID=671
# 251  https://nooksacktribe.org/departments/health/a...
#
#                           location_id   latitude   longitude  \
# 0    ae97066be6a14f53d572bcbab83d4ef4        NaN         NaN
# 1    5cbaa27bd58a2b8b728caad9c8a554bf        NaN         NaN
# 2    647b980c49850404ea2db47db8ec504c        NaN         NaN
# 3    2cc46b37742f870c0904d2a6f8adcd2e        NaN         NaN
# 4    52dbbe006552f49c9a32e5dee5e3f7ce        NaN         NaN
# ..                                ...        ...         ...
# 247  6f8fb2bc827f40c58d4af182a0673d0d  48.752213 -122.458694
# 248  d5efd61f3ff754bfb271ef5df9d8d035  48.860740 -122.584070
# 249  15af830a534f384b2e3604b4ae82a0f4  48.779087 -122.485700
# 250  0c47767855354d43ed2809cca939bdff  48.795227 -122.624560
# 251  b7d77ac93548be306d815f1eb05b5b46  48.885113 -122.347946
#
#                                    address_1 address_2        city  \
# 0                                       text      text        text
# 1                        800 Chestnut Street  Suite 1C  Bellingham
# 2                          210 Lottie Street            Bellingham
# 3                           4956 Deming Road                Deming
# 4                      3028 Lindbergh Avenue            Bellingham
# ..                                       ...       ...         ...
# 247                 1221 Fraser St,Suite E-1      None  Bellingham
# 248                     6044 Portal Way,#103      None    Ferndale
# 249                         3600 Meridian St      None  Bellingham
# 250                            2694 Kwina Rd      None  Bellingham
# 251  2505 Sulwhanon Drive,Modular Building A      None     Everson
#
#                      state_province          postal_code
# 0    Two character state (All caps)  99999 or 99999-9999
# 1                                WA                98225
# 2                                WA                98225
# 3                                WA                98244
# 4                                WA                98225
# ..                              ...                  ...
# 247                              WA                98229
# 248                              WA                98248
# 249                              WA                98225
# 250                              WA                98226
# 251                              WA                98247
#
# [252 rows x 11 columns]

# %%
results = connector.transform(dedupe_names_orgs)
# Out:
# evaluating<function dedupe_names_orgs at 0x7f0dd4611d80>
# {'name': 'o_name', 'o_url': 'o_url', 'address_1': 'address_1', 'address_2': 'address_2', 'city': 'city', 'state_province': 'state_province', 'postal_code': 'postal_code'}
# deduping
# Importing data ...
# Reading from /home/jamey/hackathon/microservice/source/silobuster-dedupe/libs/dedupe/ml/names_orgs/names_orgs_learned_settings
# Clustering...
# /home/jamey/hackathon/microservice/source/silobuster-dedupe/libs/dedupe/ml/names_orgs/names_orgs.py:40: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_final = pandas_dedupe.dedupe_dataframe(df=data, field_properties=[
# # duplicate sets 221
# fields
# ('028f7cd7-f46e-4ab9-84ef-0d17b24d27fa', 'ef9e1220-db0b-48af-abb8-afb6e4e229a3', None, 'dedupe_names_orgs', None)
# 028f7cd7-f46e-4ab9-84ef-0d17b24d27fa ef9e1220-db0b-48af-abb8-afb6e4e229a3 None dedupe_names_orgs None
# 028f7cd7-f46e-4ab9-84ef-0d17b24d27fa ef9e1220-db0b-48af-abb8-afb6e4e229a3 None dedupe_names_orgs None
# ('028f7cd7-f46e-4ab9-84ef-0d17b24d27fa', 'ef9e1220-db0b-48af-abb8-afb6e4e229a3', None, 'dedupe_names_orgs', None)
# 028f7cd7-f46e-4ab9-84ef-0d17b24d27fa ef9e1220-db0b-48af-abb8-afb6e4e229a3 None dedupe_names_orgs None

# %%
d = dict()
d['name'] = 'o_name'
connector.df.rename(d, axis=1, inplace=True)

connector.df.columns.copy()
# Out:
# Index(['organization_id', 'o_name', 'o_url', 'location_id', 'latitude',
#        'longitude', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code'],
#       dtype='object')

# %%
print (results)
# Out:
#                       organization_id  \
# 0    46c4acdfa7407bb1f0de32a2467c7987
# 1    0311533a6d3626101e12996e914c1477
# 2    c5fce969171a54cfae5440cacfd45585
# 3    7536dcaf0707e39f30ec2936a5b6774e
# 4    b3fa2d0531dc59d40be538c89a15e383
# ..                                ...
# 247  153d5b0e27aac9dce9c5bb0780140539
# 248  c37caada0542c22e1c2251a4e87a82a7
# 249  82a20fa5edd54a7ae2447e4fcb219828
# 250  b2deadfeed40efe829bcd1a0bff93f12
# 251  09f52f8f4172b0876578c593ec08ca00
#
#                                                 o_name  \
# 0                                        required text
# 1    depressive and bipolar support alliance whatco...
# 2             bellingham parks and recreation division
# 3                          mount baker school district
# 4                         bellingham technical college
# ..                                                 ...
# 247        bridges treatment and recovery (bellingham)
# 248          bridges treatment and recovery (ferndale)
# 249          lake whatcom residential treatment center
# 250                                         lummi care
# 251                        nooksack tribe (genesis ii)
#
#                                                  o_url  \
# 0                               http://some.domain.com
# 1                           http://www.dbsalliance.org
# 2                  https://cob.org/services/recreation
# 3                        http://www.mtbaker.wednet.edu
# 4                                  https://www.btc.edu
# ..                                                 ...
# 247                   https://www.bridgestreatment.com
# 248                   https://www.bridgestreatment.com
# 249       https://lwrtc.org/services/medical-services/
# 250     https://www.lummi-nsn.gov/website.phppageid671
# 251  https://nooksacktribe.org/departments/health/a...
#
#                           location_id   latitude    longitude  \
# 0    ae97066be6a14f53d572bcbab83d4ef4       None         None
# 1    5cbaa27bd58a2b8b728caad9c8a554bf       None         None
# 2    647b980c49850404ea2db47db8ec504c       None         None
# 3    2cc46b37742f870c0904d2a6f8adcd2e       None         None
# 4    52dbbe006552f49c9a32e5dee5e3f7ce       None         None
# ..                                ...        ...          ...
# 247  6f8fb2bc827f40c58d4af182a0673d0d  48.752213  -122.458694
# 248  d5efd61f3ff754bfb271ef5df9d8d035   48.86074   -122.58407
# 249  15af830a534f384b2e3604b4ae82a0f4  48.779087    -122.4857
# 250  0c47767855354d43ed2809cca939bdff  48.795227   -122.62456
# 251  b7d77ac93548be306d815f1eb05b5b46  48.885113  -122.347946
#
#                                    address_1 address_2        city  \
# 0                                       text      text        text
# 1                        800 chestnut street  suite 1c  bellingham
# 2                          210 lottie street            bellingham
# 3                           4956 deming road                deming
# 4                      3028 lindbergh avenue            bellingham
# ..                                       ...       ...         ...
# 247                 1221 fraser st,suite e-1      None  bellingham
# 248                      6044 portal way,103      None    ferndale
# 249                         3600 meridian st      None  bellingham
# 250                            2694 kwina rd      None  bellingham
# 251  2505 sulwhanon drive,modular building a      None     everson
#
#                      state_province          postal_code  cluster id  \
# 0    two character state (all caps)  99999 or 99999-9999          28
# 1                                wa                98225          29
# 2                                wa                98225          30
# 3                                wa                98244          31
# 4                                wa                98225           0
# ..                              ...                  ...         ...
# 247                              wa                98229         217
# 248                              wa                98248         218
# 249                              wa                98225          16
# 250                              wa                98226         219
# 251                              wa                98247         220
#
#      confidence
# 0      1.000000
# 1      1.000000
# 2      1.000000
# 3      1.000000
# 4      0.756544
# ..          ...
# 247    1.000000
# 248    1.000000
# 249    0.594907
# 250    1.000000
# 251    1.000000
#
# [252 rows x 13 columns]
